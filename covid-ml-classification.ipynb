# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("covid_toy.csv")
df.head(5)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
#Features and Target
x=df[['fever','cough']]
y=df['has_covid']

# %%
#Train Test split
X_train,X_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
# -----------------------------
# fever aur cough categorical hain

numeric_features = ['fever']
categorical_features = ['cough']

numeric_transformer = Pipeline([('imputer', SimpleImputer(strategy='median'))])

categorical_transformer = Pipeline(
    [('imputer', SimpleImputer(strategy='most_frequent')), ('encoder', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer([
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# %%
# 3. Preprocessing
# 4. ML Model
model = Pipeline([('preprocessor', preprocessor), ('classifier', LogisticRegression())])

# %%
# 5. Train Model
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['fever']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['cough'])])),
#                 ('classifier', LogisticRegression())])

# %%
# 6. Test Accuracy
accuracy = model.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.55

# %%
# 7. User Input

fever_input = float(input("Enter your fever temperature: "))
cough_input = input("Do you have cough? (Mild/Strong): ").strip().capitalize()

user_data = pd.DataFrame({
    'fever': [fever_input],
    'cough': [cough_input]
})

# %%
# 9. Prediction
# -----------------------------

prediction = model.predict(user_data)

probability = model.predict_proba(user_data)

print("Prediction:", prediction[0])
print("Probability:", probability[0])
# Out:
# Prediction: Yes
# Probability: [0.40212924 0.59787076]
